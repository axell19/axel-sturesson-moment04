# %%
# Importerar pandas, matplotlib och numpy för vi behöver pandas för att läsa in filen och matplotlib för att göra en graf och numpy.
import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 

# För att läsa in datan för dödsfall per kön med pandas.
df = pd.read_csv('Gender_Data.csv')

# Definierar vilka kön det är och hur många dödsfall som har skett. 
kön = ['Male', 'Female']
dödsfall = [6657, 5771]

# Använder matplotlib (förkortat "plt") och "pie" alltså "plt.pie" för att få fram ett cirkeldiagram. Sen får man skriva in värderna eller då dödsfallen och könen man vill undersöka plus andra viktiga saker som autopct och jag skrev också med shadow för det blir lite snyggare och sedan görs det om till procent och visas i cirkeldiagramet. 
plt.pie(dödsfall, labels=kön, autopct='%0.f%%', shadow=True ,startangle=90)


# Här skriver jag vad man ser i diagramet så att man förstår som användare.
print("Ett cirkeldiagram på dödsfall per kön i Sverige i procentform.")

# För att kunna se diagramet
plt.show()

# Printar datan om dödsfall per kön 
print(df)
# Out:
# Ett cirkeldiagram på dödsfall per kön i Sverige i procentform.
#    Gender  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 0    Male       288507                  3582          6657
# 1  Female       319641                  1411          5771

# %%
# Importerar samma bibliotek som förut.
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt

# Läser in datan med hjälp av pandas på dödsfall per åldrar. 
df = pd.read_csv('National_Total_Deaths_by_Age_Group.csv')

# Definierar diagram
diagram = plt.figure()

# Skapar axlarna
ax = diagram.add_axes([0,0,1,1])

# Alla åldrar i en lista
åldrar = ['0-9', '10-19', '20-29', '30-39', '40-49', '50-59', '60-69', '70-79', '80-89', '90+']

# Alla nummer av dödsfall
dödsfall = [7, 3, 15, 33, 81, 261, 721, 2605, 5239, 3463]

ax.bar(åldrar, dödsfall)

# Beskriver vad man ser i diagramet
print("Stapeldiagram för dödsfall per åldrar i Sverige")

# För att kunna se grafen 
plt.show()

# Printar datan om dödsfall per åldrar
print(df)
# Out:
# Stapeldiagram för dödsfall per åldrar i Sverige
#   Age_Group  Total_Cases  Total_ICU_Admissions  Total_Deaths
# 0       0-9         9127                    22             7
# 1     10-19        62180                    35             3
# 2     20-29       107936                   142            15
# 3     30-39       107508                   194            33
# 4     40-49       109903                   483            81
# 5     50-59       101188                  1084           261
# 6     60-69        53511                  1438           721
# 7     70-79        26476                  1259          2605
# 8     80-89        20538                   329          5239
# 9       90+         9980                     7          3463

# %%
# Gör samma här som jag har gjort i de två andra (läser in de olika biblioteken som behövs och läser in datan jag behöver)
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
df = pd.read_csv('Regional_Totals_Data.csv')

# Definierar länen jag ska jämföra och dödsfallen där.
län = ('Västra Götaland', 'Stockholm')
dödsfall = [1993, 3820]

# Skapar en pie chart funktion till att börja med.
plt.pie(dödsfall, labels=län, shadow=True, autopct='%0.f%%')

# Gör en cirkel i mitten a pie charten så att den ska se ihållig ut, måste vara samma färg som backgrundsfärgen så att illusionen fungerar. 
cirkel = plt.Circle( (0,0), 0.7, color='white')

# För att då fram den nuvarande figuren och förkortar "plt.gcf" till "p".
p=plt.gcf()

# Använder det förkortade och lägger till cirkel vi skapade i mitten av pie charten så att den blir synlig. 
p.gca().add_artist(cirkel)

# Förklarar för användaren vad man ser i diagramet. 
print("Antalet döda i Västra Götaland och Stockholm visas i procentform i en så kallat donut plot. Ett ihåligt cirkeldiagram")

# För att kunna se diagramet vi har skapat.
plt.show()

# Printar datan om dödsfall i de olika regionerna med hjälp av pandas.
print(df)
# Out:
# Antalet döda i Västra Götaland och Stockholm visas i procentform i en så kallat donut plot. Ett ihåligt cirkeldiagram
#                  Region  Total_Cases  Cases_per_100k_Pop  \
# 0              Blekinge         7646         4790.546875
# 1               Dalarna        13942         4841.543945
# 2               Gotland         2650         4439.902344
# 3             Gävleborg        19426         6759.644043
# 4               Halland        21052         6305.863770
# 5   Jämtland Härjedalen         6249         4777.157715
# 6             Jönköping        24236         6665.584961
# 7                Kalmar        10391         4233.517578
# 8             Kronoberg        13080         6492.313965
# 9            Norrbotten        10977         4389.166992
# 10                Skåne       103958         7545.069336
# 11            Stockholm       144522         6079.809570
# 12             Sörmland        12214         4104.994141
# ...
