# %%
# 1 
# a) 2 706 467 personer försvarsarbetade 2019

# b) 1 070 645 personer försvararbetade inte 2019

# c) 

import pandas as pd 
import matplotlib.pyplot as plt 
import numpy as np 

Försvarsarbetande = ['Ja', 'Nej']
Antal = [2706467, 1070645]

plt.pie(Antal, labels=Försvarsarbetande, autopct='%0.f%%',)

plt.show()
